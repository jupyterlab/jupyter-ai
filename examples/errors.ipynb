# %%
# %reload_ext jupyter_ai

# %%
2/2
# Out:
# 1.0

# %%
2/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 2/0
#
# ZeroDivisionError: division by zero

# %%
print(Err[3])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 2/0
#
# ZeroDivisionError: division by zero

# %%
# %%ai chatgpt
# Explain the following Python error:
#     {Err[3]}
# Out:
# This error is a `ZeroDivisionError` which occurs when trying to divide a number by zero. In the given code, the program is trying to divide the number 2 by 0 which is not possible and hence the error is raised.
