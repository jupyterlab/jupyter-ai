# %% [markdown]
# # AI commands
#
# You can use the `%ai` cell magic to run special commands. If a model has the same name as a command, you will need to refer to the model using the `provider:model` format only; the `model` shortcut will not work.

# %%
# %reload_ext jupyter_ai

# %% [markdown]
# ## Getting help
#
# `%ai help` will show you a list of all supported commands.

# %%
# %ai help
# Out:
# help - Display a list of supported commands
# list - Display a list of models that you can use (optionally, for a single provider)
# register - Add a custom LangChain chain or alias to a model for use with %ai magic commands.Usage: `%ai register NAME CHAIN_OR_MODEL`

# %%
# %ai error chatgpt
# Out:
# There have been no errors since the kernel started.

# %%
# %ai foo
# Out:
# Cannot determine model provider from model ID 'foo'.
#
# To see a list of models you can use, run '%ai list'
#
# If you were trying to run a command, run '%ai help' to see a list of commands.

# %%
# %ai list
# Out:
# ai21
# Requires environment variable AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# anthropic
# Requires environment variable ANTHROPIC_API_KEY (not set)
# * anthropic:claude-v1
# * anthropic:claude-v1.0
# * anthropic:claude-v1.2
# * anthropic:claude-instant-v1
# * anthropic:claude-instant-v1.0
#
# cohere
# Requires environment variable COHERE_API_KEY (not set)
# * cohere:medium
# * cohere:xlarge
#
# huggingface_hub
# Requires environment variable HUGGINGFACEHUB_API_TOKEN (not set)
# * This provider does not define a list of models.
#
# openai
# Requires environment variable OPENAI_API_KEY (not set)
# * openai:text-davinci-003
# * openai:text-davinci-002
# * openai:text-curie-001
# * openai:text-babbage-001
# * openai:text-ada-001
# * openai:davinci
# * openai:curie
# * openai:babbage
# * openai:ada
#
# openai-chat
# Requires environment variable OPENAI_API_KEY (not set)
# * openai-chat:gpt-4
# * openai-chat:gpt-4-0314
# * openai-chat:gpt-4-32k
# * openai-chat:gpt-4-32k-0314
# * openai-chat:gpt-3.5-turbo
# * openai-chat:gpt-3.5-turbo-0301
#
# openai-chat-new
# Requires environment variable OPENAI_API_KEY (set)
# * openai-chat-new:gpt-4
# * openai-chat-new:gpt-4-0314
# * openai-chat-new:gpt-4-32k
# * openai-chat-new:gpt-4-32k-0314
# * openai-chat-new:gpt-3.5-turbo
# * openai-chat-new:gpt-3.5-turbo-0301
#
# sagemaker-endpoint
# * This provider does not define a list of models.

# %%
# %ai list openai
# Out:
# openai
# Requires environment variable OPENAI_API_KEY (not set)
# * openai:text-davinci-003
# * openai:text-davinci-002
# * openai:text-curie-001
# * openai:text-babbage-001
# * openai:text-ada-001
# * openai:davinci
# * openai:curie
# * openai:babbage
# * openai:ada

# %%
# %ai register foo
# Out:
# Usage: %ai register NAME CHAIN_OR_MODEL

# %%
# %ai register foo bar
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_line_magic('ai', 'register foo bar')
#
# File /opt/miniconda3/envs/jupyter-ai/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:400, in AiMagics.ai(self, line, cell)
#     397 # If the user is attempting to run a command, run the command separately.
#     398 if (args.model_id in AI_COMMANDS):
#     399     # The "prompt" is a list of arguments to the command, whitespace-delimited
# --> 400     return self._ai_command(args.model_id, prompt)
#     402 # Apply a prompt template.
#     403 prompt = PROMPT_TEMPLATES_BY_FORMAT[args.format].format(prompt = prompt)
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:318, in AiMagics._ai_command(self, command, args_string)
#     314     register_name = args[0]
#     315     variable_name = args[1]
#     317     return TextOrMarkdown(
# --> 318         self._ai_register_command_text(register_name, variable_name),
#     319         self._ai_register_command_markdown(register_name, variable_name)
#     320     )
#     321 else:
#     322     # This should be unreachable, since unhandled commands are treated like model names
#     323     return TextOrMarkdown(
#     324         f"No handler for command {command}\n",
#     325         f"No handler for command `{command}`"
#     326     )
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:243, in AiMagics._ai_register_command_text(self, register_name, variable_name)
#     242 def _ai_register_command_text(self, register_name, variable_name):
# --> 243     self._register_name(register_name, variable_name)
#     244     output = f"Registered new name {register_name}"
#     246     return output
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:234, in AiMagics._register_name(self, register_name, variable_name)
#     232         return None # No error
#     233     else:
# --> 234         raise ValueError('Target model was not specified in PROVIDER_ID:MODEL_NAME format')
#     236 return None
#
# ValueError: Target model was not specified in PROVIDER_ID:MODEL_NAME format

# %%
# %ai register list bar
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('ai', 'register list bar')
#
# File /opt/miniconda3/envs/jupyter-ai/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:400, in AiMagics.ai(self, line, cell)
#     397 # If the user is attempting to run a command, run the command separately.
#     398 if (args.model_id in AI_COMMANDS):
#     399     # The "prompt" is a list of arguments to the command, whitespace-delimited
# --> 400     return self._ai_command(args.model_id, prompt)
#     402 # Apply a prompt template.
#     403 prompt = PROMPT_TEMPLATES_BY_FORMAT[args.format].format(prompt = prompt)
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:318, in AiMagics._ai_command(self, command, args_string)
#     314     register_name = args[0]
#     315     variable_name = args[1]
#     317     return TextOrMarkdown(
# --> 318         self._ai_register_command_text(register_name, variable_name),
#     319         self._ai_register_command_markdown(register_name, variable_name)
#     320     )
#     321 else:
#     322     # This should be unreachable, since unhandled commands are treated like model names
#     323     return TextOrMarkdown(
#     324         f"No handler for command {command}\n",
#     325         f"No handler for command `{command}`"
#     326     )
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:243, in AiMagics._ai_register_command_text(self, register_name, variable_name)
#     242 def _ai_register_command_text(self, register_name, variable_name):
# --> 243     self._register_name(register_name, variable_name)
#     244     output = f"Registered new name {register_name}"
#     246     return output
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:213, in AiMagics._register_name(self, register_name, variable_name)
#     210 def _register_name(self, register_name, variable_name):
#     211     # Existing command names are not allowed
#     212     if (register_name in AI_COMMANDS):
# --> 213         raise ValueError('This name is reserved for a command')
#     215     # Existing registered names are not allowed
#     216     if (register_name in self.custom_model_registry):
#     217         # TODO: Recommend 'update' command
#
# ValueError: This name is reserved for a command

# %%
# %ai register foo:bar baz
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_line_magic('ai', 'register foo:bar baz')
#
# File /opt/miniconda3/envs/jupyter-ai/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:400, in AiMagics.ai(self, line, cell)
#     397 # If the user is attempting to run a command, run the command separately.
#     398 if (args.model_id in AI_COMMANDS):
#     399     # The "prompt" is a list of arguments to the command, whitespace-delimited
# --> 400     return self._ai_command(args.model_id, prompt)
#     402 # Apply a prompt template.
#     403 prompt = PROMPT_TEMPLATES_BY_FORMAT[args.format].format(prompt = prompt)
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:318, in AiMagics._ai_command(self, command, args_string)
#     314     register_name = args[0]
#     315     variable_name = args[1]
#     317     return TextOrMarkdown(
# --> 318         self._ai_register_command_text(register_name, variable_name),
#     319         self._ai_register_command_markdown(register_name, variable_name)
#     320     )
#     321 else:
#     322     # This should be unreachable, since unhandled commands are treated like model names
#     323     return TextOrMarkdown(
#     324         f"No handler for command {command}\n",
#     325         f"No handler for command `{command}`"
#     326     )
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:243, in AiMagics._ai_register_command_text(self, register_name, variable_name)
#     242 def _ai_register_command_text(self, register_name, variable_name):
# --> 243     self._register_name(register_name, variable_name)
#     244     output = f"Registered new name {register_name}"
#     246     return output
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:224, in AiMagics._register_name(self, register_name, variable_name)
#     222 acceptable_name = re.compile('^[a-zA-Z0-9._-]+$')
#     223 if (not acceptable_name.match(register_name)):
# --> 224     raise ValueError('A registry name may contain ASCII letters, numbers, hyphens, underscores, '
#     225         + 'and periods. No other characters, including a colon, are permitted')
#     227 # If variable_name is a string, treat this as an alias.
#     228 if (isinstance(variable_name, str)):
#
# ValueError: A registry name may contain ASCII letters, numbers, hyphens, underscores, and periods. No other characters, including a colon, are permitted

# %%
# %ai register mychat openai-chat:gpt-4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_line_magic('ai', 'register mychat openai-chat:gpt-4')
#
# File /opt/miniconda3/envs/jupyter-ai/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:400, in AiMagics.ai(self, line, cell)
#     397 # If the user is attempting to run a command, run the command separately.
#     398 if (args.model_id in AI_COMMANDS):
#     399     # The "prompt" is a list of arguments to the command, whitespace-delimited
# --> 400     return self._ai_command(args.model_id, prompt)
#     402 # Apply a prompt template.
#     403 prompt = PROMPT_TEMPLATES_BY_FORMAT[args.format].format(prompt = prompt)
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:319, in AiMagics._ai_command(self, command, args_string)
#     314     register_name = args[0]
#     315     variable_name = args[1]
#     317     return TextOrMarkdown(
#     318         self._ai_register_command_text(register_name, variable_name),
# --> 319         self._ai_register_command_markdown(register_name, variable_name)
#     320     )
#     321 else:
#     322     # This should be unreachable, since unhandled commands are treated like model names
#     323     return TextOrMarkdown(
#     324         f"No handler for command {command}\n",
#     325         f"No handler for command `{command}`"
#     326     )
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:240, in AiMagics._ai_register_command_markdown(self, register_name, variable_name)
#     238 def _ai_register_command_markdown(self, register_name, variable_name):
#     239     # TODO: Write this method
# --> 240     return self._ai_register_command_text(register_name, variable_name)
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:243, in AiMagics._ai_register_command_text(self, register_name, variable_name)
#     242 def _ai_register_command_text(self, register_name, variable_name):
# --> 243     self._register_name(register_name, variable_name)
#     244     output = f"Registered new name {register_name}"
#     246     return output
#
# File ~/git/jupyter-ai/packages/jupyter-ai-magics/jupyter_ai_magics/magics.py:218, in AiMagics._register_name(self, register_name, variable_name)
#     215 # Existing registered names are not allowed
#     216 if (register_name in self.custom_model_registry):
#     217     # TODO: Recommend 'update' command
# --> 218     raise ValueError('This name is already associated with a custom model')
#     220 # A registry name contains ASCII letters, numbers, hyphens, underscores,
#     221 # and periods. No other characters, including a colon, are permitted
#     222 acceptable_name = re.compile('^[a-zA-Z0-9._-]+$')
#
# ValueError: This name is already associated with a custom model

# %%
# %ai list
# Out:
# ai21
# Requires environment variable AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# anthropic
# Requires environment variable ANTHROPIC_API_KEY (not set)
# * anthropic:claude-v1
# * anthropic:claude-v1.0
# * anthropic:claude-v1.2
# * anthropic:claude-instant-v1
# * anthropic:claude-instant-v1.0
#
# cohere
# Requires environment variable COHERE_API_KEY (not set)
# * cohere:medium
# * cohere:xlarge
#
# huggingface_hub
# Requires environment variable HUGGINGFACEHUB_API_TOKEN (not set)
# * This provider does not define a list of models.
#
# openai
# Requires environment variable OPENAI_API_KEY (not set)
# * openai:text-davinci-003
# * openai:text-davinci-002
# * openai:text-curie-001
# * openai:text-babbage-001
# * openai:text-ada-001
# * openai:davinci
# * openai:curie
# * openai:babbage
# * openai:ada
#
# openai-chat
# Requires environment variable OPENAI_API_KEY (not set)
# * openai-chat:gpt-4
# * openai-chat:gpt-4-0314
# * openai-chat:gpt-4-32k
# * openai-chat:gpt-4-32k-0314
# * openai-chat:gpt-3.5-turbo
# * openai-chat:gpt-3.5-turbo-0301
#
# sagemaker-endpoint
# * This provider does not define a list of models.
